# %% [markdown]
# <a href="https://colab.research.google.com/github/arivval123/D4-matrikulasi/blob/main/tugas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %%
print('Gamma Correction pada citra')
print('--------------------------------')
try:
  bit = int(input('Masukan Nilai bit depth : '))
except ValueError:
  print('Error, not a number')
  

img = cv.imread('/content/drive/MyDrive/PCVK/female.tiff', cv.IMREAD_GRAYSCALE)
depth_image = np.zeros(img.shape, img.dtype)

level = 255/(2**bit)-1

for y in range(img.shape[0]):
  for x in range(img.shape[1]):
    depth_image[y,x] = np.clip(round(img[y,x]/level) * level, 0, 255)

final_frame = cv.hconcat((img, depth_image))
cv2_imshow(final_frame)
# Out:
# Gamma Correction pada citra
# --------------------------------
# Masukan Nilai bit depth : 3
# <PIL.Image.Image image mode=L size=512x256 at 0x7F5514ADE250>

# %%
import glob
from math import log10, sqrt
  
original = cv.imread('/content/drive/MyDrive/PCVK/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/pcvk/noises/*.jpg'):
    n = cv.imread(img)
    cv_img.append👎

dst = cv_img[0]
noise_number = 4 # nomor (array) gambar pada folder noises
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0
# Out:
#   File "<ipython-input-8-60302a38d6f9>", line 8
#     cv_img.append👎
#                  ^
# SyntaxError: invalid character in identifier

# %%
def PSNR(original, compressed): 
    mse = np.mean((original - compressed) ** 2) 
    if(mse == 0):  # MSE is zero means no noise is present in the signal. 
                  # Therefore PSNR have no importance. 
        return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse)) 
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ff30262cc69e> in <module>
#       8     return psnr
#       9
# ---> 10 compressed = dst
#      11 psnr = PSNR(original, compressed)
#      12
#
# NameError: name 'dst' is not defined

# %%
#Citra = 30
dst = cv_img[0]
noise_number = 29
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame
# Out:
#   File "<ipython-input-7-66d1cb971528>", line 17
#     cv2_imshow(galaxy_frame
#                            ^
# SyntaxError: unexpected EOF while parsing
